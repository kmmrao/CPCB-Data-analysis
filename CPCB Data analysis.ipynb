# %%
cd C:\Users\IITM\Downloads
# Out:
# C:\Users\IITM\Downloads

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
import matplotlib.font_manager as font_manager

# %%
Haldia_WB                              = pd.read_excel('Haldia_WB.xlsx',skiprows=16,usecols='A:G',nrows= 762)
Belur_Math_Howrah_WB                   = pd.read_excel('Belur Math_Howrah_WB.xlsx',skiprows=16,usecols='A:G',nrows= 762)
Ghusuri_Howrah_WB                      = pd.read_excel('Ghusuri_Howrah_WB.xlsx',skiprows=16,usecols='A:G',nrows= 762)
Padmapukur_Howrah_WB                   = pd.read_excel('Padmapukur_Howrah_WB.xlsx',skiprows=16,usecols='A:G',nrows= 762)
Ballygunge_Kolkata_WB                  = pd.read_excel('Ballygunge_Kolkata_WB.xlsx',skiprows=16,usecols='A:G',nrows= 762)
Bidhannagar_Kolkata_WB                 = pd.read_excel('Bidhannagar_Kolkata_WB.xlsx',skiprows=16,usecols='A:G',nrows= 762)
William_Kolkata_WB                     = pd.read_excel('William_Kolkata_WB.xlsx',skiprows=16,usecols='A:G',nrows= 762)
Jadavpur_Kolkata_WB                    = pd.read_excel('Jadavpur_Kolkata_WB.xlsx',skiprows=16,usecols='A:G',nrows= 762)
Rabindra_Bharati_University_Kolkata_WB = pd.read_excel('Rabindra Bharati University_Kolkata_WB.xlsx',skiprows=16,usecols='A:G',nrows= 762)
Rabindra_Sarobar_Kolkata_WB            = pd.read_excel('Rabindra Sarobar_Kolkata_WB.xlsx',skiprows=16,usecols='A:G',nrows= 762)
Victoria_Kolkata_WB                    = pd.read_excel('Victoria_Kolkata_WB.xlsx',skiprows=16,usecols='A:G',nrows= 762)
Ward_Bapupara_Siliguri_WB              = pd.read_excel('Ward-32 Bapupara_Siliguri_WB.xlsx',skiprows=16,usecols='A:G',nrows= 762)
Bardowali_Agartala_Tripura             = pd.read_excel('Bardowali_Agartala_Tripura.xlsx',skiprows=16,usecols='A:G',nrows= 762)
Kunjaban_Agartala_Tripura              = pd.read_excel('Kunjaban_Agartala_Tripura.xlsx',skiprows=16,usecols='A:G',nrows= 762)
Durgapur_WB                            = pd.read_excel('Durgapur_WB.xlsx',skiprows=16,usecols='A:G',nrows= 762)
Asansol_WB                             = pd.read_excel('Asansol_WB.xlsx',skiprows=16,usecols='A:G',nrows= 762)

# %%
Haldia_WB['From Date']                   = pd.to_datetime(Haldia_WB['From Date'], format="%d-%m-%Y %H:%M")
Belur_Math_Howrah_WB['From Date']        = pd.to_datetime(Belur_Math_Howrah_WB['From Date'], format="%d-%m-%Y %H:%M")
Ghusuri_Howrah_WB['From Date']           = pd.to_datetime(Ghusuri_Howrah_WB['From Date'], format="%d-%m-%Y %H:%M")
Padmapukur_Howrah_WB['From Date']        = pd.to_datetime(Padmapukur_Howrah_WB['From Date'], format="%d-%m-%Y %H:%M")
Ballygunge_Kolkata_WB['From Date']       = pd.to_datetime(Ballygunge_Kolkata_WB['From Date'], format="%d-%m-%Y %H:%M")
Bidhannagar_Kolkata_WB['From Date']      = pd.to_datetime(Bidhannagar_Kolkata_WB['From Date'], format="%d-%m-%Y %H:%M")
William_Kolkata_WB['From Date']          = pd.to_datetime(William_Kolkata_WB['From Date'], format="%d-%m-%Y %H:%M")
Jadavpur_Kolkata_WB['From Date']         = pd.to_datetime(Jadavpur_Kolkata_WB['From Date'], format="%d-%m-%Y %H:%M")
Rabindra_Bharati_University_Kolkata_WB['From Date'] = pd.to_datetime(Rabindra_Bharati_University_Kolkata_WB['From Date'], format="%d-%m-%Y %H:%M")
Rabindra_Sarobar_Kolkata_WB['From Date'] = pd.to_datetime(Rabindra_Sarobar_Kolkata_WB['From Date'], format="%d-%m-%Y %H:%M")
Victoria_Kolkata_WB['From Date'] = pd.to_datetime(Victoria_Kolkata_WB['From Date'], format="%d-%m-%Y %H:%M")
Ward_Bapupara_Siliguri_WB['From Date']   = pd.to_datetime(Ward_Bapupara_Siliguri_WB['From Date'], format="%d-%m-%Y %H:%M")
Bardowali_Agartala_Tripura['From Date']  = pd.to_datetime(Bardowali_Agartala_Tripura['From Date'], format="%d-%m-%Y %H:%M")
Kunjaban_Agartala_Tripura['From Date']   = pd.to_datetime(Kunjaban_Agartala_Tripura['From Date'], format="%d-%m-%Y %H:%M")
Durgapur_WB['From Date']                 = pd.to_datetime(Durgapur_WB['From Date'], format="%d-%m-%Y %H:%M")
Asansol_WB['From Date']                  = pd.to_datetime(Asansol_WB['From Date'], format="%d-%m-%Y %H:%M")

# %%
Haldia_WB = Haldia_WB.replace(['None'], np.nan)
Belur_Math_Howrah_WB=Belur_Math_Howrah_WB.replace(['None'], np.nan)
Ghusuri_Howrah_WB=Ghusuri_Howrah_WB.replace(['None'], np.nan)
Padmapukur_Howrah_WB=Padmapukur_Howrah_WB.replace(['None'], np.nan)
Ballygunge_Kolkata_WB=Ballygunge_Kolkata_WB.replace(['None'], np.nan)
Bidhannagar_Kolkata_WB=Bidhannagar_Kolkata_WB.replace(['None'], np.nan)
William_Kolkata_WB=William_Kolkata_WB.replace(['None'], np.nan)
Jadavpur_Kolkata_WB=Jadavpur_Kolkata_WB.replace(['None'], np.nan)
Rabindra_Bharati_University_Kolkata_WB=Rabindra_Bharati_University_Kolkata_WB.replace(['None'], np.nan)
Rabindra_Sarobar_Kolkata_WB=Rabindra_Sarobar_Kolkata_WB.replace(['None'], np.nan)
Victoria_Kolkata_WB=Victoria_Kolkata_WB.replace(['None'], np.nan)
Ward_Bapupara_Siliguri_WB=Ward_Bapupara_Siliguri_WB.replace(['None'], np.nan)
Bardowali_Agartala_Tripura=Bardowali_Agartala_Tripura.replace(['None'], np.nan)
Kunjaban_Agartala_Tripura=Kunjaban_Agartala_Tripura.replace(['None'], np.nan)
Durgapur_WB=Durgapur_WB.replace(['None'], np.nan)
Asansol_WB=Asansol_WB.replace(['None'], np.nan)

# %%
Haldia_WB.columns
# Out:
# Index(['From Date', 'To Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx'], dtype='object')

# %%
[408:744]

# %%
fig=plt.figure(figsize=(13.5,4))#,constrained_layout=True)
ax = fig.subplots_adjust(bottom=0.1, top=0.9, left=0.1, right=0.8,wspace=0.02, hspace=0.02)

font = font_manager.FontProperties(family='Arial',
                                   weight='bold',
                                   style='normal', size=15)
days= ['2022-10-18','2022-10-19','2022-10-20','2022-10-21','2022-10-22','2022-10-23',
      '2022-10-24','2022-10-25','2022-10-26','2022-10-27','2022-10-28','2022-10-29',
      '2022-10-30','2022-10-31','2022-11-01']
con = [0,25,50,75,100,125,150]#,200,250,300,350]
ax1 = plt.subplot()#1,3, 1)        
# ax1.plot(Haldia_WB['From Date'][408:744],Haldia_WB['PM2.5'][408:744],label = 'Haldia_WB',c='red')
# ax1.plot(Belur_Math_Howrah_WB['From Date'][408:744],Belur_Math_Howrah_WB['PM2.5'][408:744],label = 'Belur_Math_WB',c='red')
# ax1.plot(Ghusuri_Howrah_WB['From Date'][408:744],Ghusuri_Howrah_WB['PM2.5'][408:744],label = 'Ghusuri_WB',c='red')
# ax1.plot(Padmapukur_Howrah_WB['From Date'][408:744],Padmapukur_Howrah_WB['PM2.5'][408:744],label = 'Padmapukur_WB',c='red')
# ax1.plot(Ballygunge_Kolkata_WB['From Date'][408:744],Ballygunge_Kolkata_WB['PM2.5'][408:744],label = 'Ballygunge_WB',c='red')
# ax1.plot(Bidhannagar_Kolkata_WB['From Date'][408:744],Bidhannagar_Kolkata_WB['PM2.5'][408:744],label = 'Bidhannagar_WB',c='red')
# ax1.plot(William_Kolkata_WB['From Date'][408:744],William_Kolkata_WB['PM2.5'][408:744],label = 'William_WB',c='red')
# ax1.plot(Jadavpur_Kolkata_WB['From Date'][408:744],Jadavpur_Kolkata_WB['PM2.5'][408:744],label = 'Jadavpur_WB',c='red')
# ax1.plot(Rabindra_Bharati_University_Kolkata_WB['From Date'][408:744],Rabindra_Bharati_University_Kolkata_WB['PM2.5'][408:744],label = 'Rabindra_Bharati_Uni_WB',c='red')
# ax1.plot(Rabindra_Sarobar_Kolkata_WB['From Date'][408:744],Rabindra_Sarobar_Kolkata_WB['PM2.5'][408:744],label = 'Rabindra_Saro_WB',c='red')
# ax1.plot(Victoria_Kolkata_WB['From Date'][408:744],Victoria_Kolkata_WB['PM2.5'][408:744],label = 'Victoria_WB',c='red')
# ax1.plot(Ward_Bapupara_Siliguri_WB['From Date'][408:744],Ward_Bapupara_Siliguri_WB['PM2.5'][408:744],label = 'iliguri_WB',c='red')
# ax1.plot(Bardowali_Agartala_Tripura['From Date'][408:744],Bardowali_Agartala_Tripura['PM2.5'][408:744],label = 'Bardowali_Agartala',c='red')
# ax1.plot(Kunjaban_Agartala_Tripura['From Date'][408:744],Kunjaban_Agartala_Tripura['PM2.5'][408:744],label = 'Kunjaban_Agartala',c='red')
# ax1.plot(Durgapur_WB['From Date'][408:744],Durgapur_WB['PM2.5'][408:744],label = 'Durgapur_WB',c='red')
ax1.plot(Asansol_WB['From Date'][408:744],Asansol_WB['PM2.5'][408:744],label = 'Asansol_WB',c='red')

ax1.set_ylim(0,150)
# ax1.set_xlim(0,40)
ax1.grid()
ax1.set_title('PM 2.5 from Asansol WB',fontweight="bold", size=20,family= 'Arial')
ax1.set_xticks(days)
ax1.set_yticks(con)
# plt.legend(prop={'family': 'Arial',"size":15,'weight':'bold'})
# ax1.legend(loc="upper left",prop=font, mode = "expand", ncol = 3)
# ax1.set_xticks(['2022-10-01','2022-10-10','2022-10-20','2022-10-24'])#,'2022-10-30'])
# ax1.set_yticks([0,0.5,1.0,1.5,2.0,2.5,3.0,3.5])
for tick in ax1.get_xticklabels():
    tick.set_rotation(90)
for tick in ax1.yaxis.get_major_ticks():
    tick.label1.set_fontsize(15)
    tick.label1.set_fontweight('bold')
for tick in ax1.xaxis.get_major_ticks():
    tick.label1.set_fontsize(15)
    tick.label1.set_fontweight('bold')
ax1.tick_params(axis='x', labelsize=15)
ax1.spines["left"].set_linewidth(2)
ax1.spines["right"].set_linewidth(2)
ax1.spines["top"].set_linewidth(2)
ax1.spines["bottom"].set_linewidth(2)
ax1.tick_params(axis='both', which='major', labelsize=15) 
for tick in ax1.get_xticklabels():
    tick.set_fontname("Arial")
for tick in ax1.get_yticklabels():
    tick.set_fontname("Arial")
    
fig.text(-0.01, 0.6, 'Concentration(\u03BC/m3)', va='center', rotation='vertical',fontsize=15,fontweight='bold',style='normal',        
         fontname='Arial')
# fig.text(0.45, -0.025, 'Time', ha='center',fontsize=15,fontweight='bold',style='normal',
#         fontname='Arial')
plt.tight_layout()
plt.savefig('PM_2_5_CPCB_Asansol_WB.jpg',bbox_inches='tight',dpi=720)

# %%
Asansol_WB['From Date'][408:744]
# Out:
# 408   2022-10-18 00:00:00
# 409   2022-10-18 01:00:00
# 410   2022-10-18 02:00:00
# 411   2022-10-18 03:00:00
# 412   2022-10-18 04:00:00
#               ...
# 739   2022-10-31 19:00:00
# 740   2022-10-31 20:00:00
# 741   2022-10-31 21:00:00
# 742   2022-10-31 22:00:00
# 743   2022-10-31 23:00:00
# Name: From Date, Length: 336, dtype: datetime64[ns]
